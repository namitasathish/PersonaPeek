# %% [markdown]
# <a href="https://colab.research.google.com/github/namitasathish/PersonaPeek/blob/main/PersonaPeek.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
data = pd.read_csv('MBTI 500.csv')

# %%
data.head()
# Out:
#                                                posts  type
# 0  know intj tool use interaction people excuse a...  INTJ
# 1  rap music ehh opp yeah know valid well know fa...  INTJ
# 2  preferably p hd low except wew lad video p min...  INTJ
# 3  drink like wish could drink red wine give head...  INTJ
# 4  space program ah bad deal meing freelance max ...  INTJ

# %%
posts = data['posts']
types = data['type']

# %%
vectorizer = TfidfVectorizer(stop_words='english')

# %%
post_vectors = vectorizer.fit_transform(posts)

# %%
def get_personality_type(user_input):
    # Transform the user input into TF-IDF vector
    user_vector = vectorizer.transform([user_input])

    # Calculate cosine similarity between user input and all posts
    similarities = cosine_similarity(user_vector, post_vectors)

    # Find the index of the most similar post
    most_similar_index = similarities.argmax()

    # Return the corresponding personality type
    return types.iloc[most_similar_index]

# %%
def ask_questions():
    print("Please answer the following questions:")
    user_responses = []

    # Expanded set of questions
    questions = [
        "How do you like to start your day?\n1. With a detailed plan\n2. By going with the flow\n3. By setting a few key priorities\n4. By tackling urgent tasks first",

        "How do you feel about large social gatherings?\n1. Energized and excited\n2. Neutral\n3. Overwhelmed but manageable\n4. Drained and prefer to avoid them",

        "What's your ideal weekend activity?\n1. Exploring new hobbies or adventures\n2. Relaxing at home with a good book\n3. Attending social gatherings and events\n4. Working on personal projects or goals",

        "When faced with a new challenge, how do you respond?\n1. Jump in and figure it out as I go\n2. Research thoroughly and plan my approach\n3. Seek advice from others before proceeding\n4. Use my past experiences to guide me",

        "When meeting new people, how do you typically react?\n1. Initiate conversation and take the lead\n2. Join in and contribute to the conversation\n3. Wait for others to approach me\n4. Prefer to observe and stay quiet",

        "How do you prefer to make decisions?\n1. Based on data and analysis\n2. By trusting my instincts and gut feeling\n3. Through collaboration and input from others\n4. By considering all possible options and outcomes",

        "What’s your approach to setting goals?\n1. Setting ambitious long-term goals\n2. Focusing on short-term milestones\n3. Creating a detailed action plan\n4. Adjusting goals based on progress and feedback",

        "How do you prefer to spend your free time?\n1. Engaging in creative projects\n2. Relaxing and unwinding\n3. Socializing and meeting new people\n4. Learning and developing new skills",

        "How do you prefer to spend your weekends?\n1. Attending events and parties with friends\n2. Engaging in group activities\n3. Spending time with a small circle of close friends\n4. Enjoying solitary or quiet activities",

        "How do you deal with conflicting opinions?\n1. By actively listening and finding common ground\n2. By sticking to my own perspective\n3. By seeking a compromise or middle ground\n4. By evaluating the evidence and making an informed decision",

        "What’s your preferred way to learn?\n1. Through hands-on experience\n2. By studying theory and concepts\n3. By discussing and debating with others\n4. By observing and analyzing examples",

        "How do you handle unexpected events?\n1. By staying calm and adapting quickly\n2. By making a detailed plan to address the situation\n3. By seeking support and advice from others\n4. By sticking to my original plan as much as possible",

        "What type of project excites you the most?\n1. Innovative and groundbreaking\n2. Well-defined and structured\n3. Collaborative and team-oriented\n4. Independent and self-driven",

        "How do you prefer to communicate?\n1. Directly and clearly\n2. Through detailed written communication\n3. In a casual and informal manner\n4. By using visual aids and demonstrations",

        "What motivates you in your work?\n1. Achieving high performance and recognition\n2. Personal growth and development\n3. Contributing to a team’s success\n4. Solving complex problems and challenges",

        "What’s your approach to networking events?\n1. Actively seek out new connections and introduce myself to everyone\n2. Engage with those who approach me\n3. Network with a few people and focus on meaningful conversations\n4. Avoid them if possible and stay in the background",

        "How do you approach organizing tasks?\n1. By creating detailed to-do lists\n2. By prioritizing tasks based on importance\n3. By setting deadlines and reminders\n4. By tackling tasks as they come up",

        "How do you prefer to receive feedback?\n1. In a structured and detailed manner\n2. As informal and spontaneous comments\n3. Through regular performance reviews\n4. By having one-on-one discussions",

        "What’s your approach to working on a team project?\n1. Taking charge and leading the team\n2. Collaborating and contributing ideas\n3. Supporting and assisting others\n4. Working independently but coordinating with the team",

        "How do you react to criticism?\n1. By analyzing it objectively and improving\n2. By discussing it to understand different perspectives\n3. By considering it but relying on my own judgment\n4. By using it as motivation to prove myself",

        "How do you feel about being the center of attention?\n1. Comfortable and enjoy it\n2. Fine with it in certain situations\n3. Prefer to share the spotlight\n4. Uncomfortable and prefer not to be the focus",

        "What kind of work environment do you thrive in?\n1. Fast-paced and ever-changing\n2. Quiet and focused\n3. Collaborative and team-oriented\n4. Flexible and self-directed",

        "How do you prefer to spend your vacation?\n1. Traveling to new places and meeting new people\n2. Going on adventures with friends\n3. Relaxing with close family and friends\n4. Having a quiet staycation or solo retreat",

        "How do you like to celebrate accomplishments?\n1. By treating myself to something special\n2. By sharing the success with others\n3. By reflecting on the achievement and setting new goals\n4. By planning a future challenge or project",

        "How do you prefer to celebrate your achievements?\n1. Throwing a big party with friends and family\n2. Sharing the news with my close circle\n3. Acknowledging it personally and quietly\n4. Keeping it low-key and focusing on the next goal",

        "How do you react to unexpected social invitations?\n1. Excited and eager to go\n2. Open but need to check my schedule\n3. Hesitant but willing if it’s important\n4. Prefer to stay in and skip it",
    ]



    for question in questions:
        response = input(question + " ")
        user_responses.append(response)
        print("\n")

    # Combine user responses into a single string
    user_input = ' '.join(user_responses)

    # Get the most likely personality type
    personality_type = get_personality_type(user_input)

    print(f"Based on your responses, your personality type is: {personality_type}")

# %%
if __name__ == "__main__":
    ask_questions()
# Out:
# Please answer the following questions:
# How do you like to start your day?
# 1. With a detailed plan
# 2. By going with the flow
# 3. By setting a few key priorities
# 4. By tackling urgent tasks first With a detailed plan
#
#
# How do you feel about large social gatherings?
# 1. Energized and excited
# 2. Neutral
# 3. Overwhelmed but manageable
# 4. Drained and prefer to avoid them Energized and excited
#
#
# What's your ideal weekend activity?
# 1. Exploring new hobbies or adventures
# 2. Relaxing at home with a good book
# 3. Attending social gatherings and events
# 4. Working on personal projects or goals  Working on personal projects or goals
#
#
# When faced with a new challenge, how do you respond?
# 1. Jump in and figure it out as I go
# 2. Research thoroughly and plan my approach
# 3. Seek advice from others before proceeding
# 4. Use my past experiences to guide me Research thoroughly and plan my approach
#
#
# When meeting new people, how do you typically react?
# ...
